# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel("/content/samydata.xlsx")

# %%
data.head()
# Out:
#    YEAR      GDP   GDP_DEFLATOR     Inv  Imports   Exports      Go     ER  \
# 0  1980   74.940          6.622  25.526     12.5      -0.1  20.010   7.42
# 1  1981   86.061          7.305  26.988    -19.7      -4.2  20.000   9.05
# 2  1982  100.034          8.082  24.423    -17.5       3.2  21.554  10.92
# 3  1983  112.748          8.967  23.974    -18.1       1.2  21.960  13.31
# 4  1984  126.675          9.916  22.433     17.9       0.9  25.088  14.41
#
#           TOT
# 0 -125.000000
# 1    4.690476
# 2   -5.468750
# 3  -15.083333
# 4   19.888889

# %%
data.isna().sum()
# Out:
# YEAR             0
# GDP              0
#  GDP_DEFLATOR    0
#  Inv             0
# Imports          0
#  Exports         0
#  Go              0
#  ER              0
# TOT              0
# dtype: int64

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(data.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap of the variables', fontdict={'fontsize':12}, pad=12);

# %%
sns.pairplot(data)

# %%
data.describe()
# Out:
#               YEAR           GDP   GDP_DEFLATOR        Inv    Imports  \
# count    41.000000     41.000000      41.000000  41.000000  41.000000
# mean   2000.000000   2358.541951      68.485951  20.011732   4.160683
# std      11.979149   2939.660036      59.941092   4.214886  11.189371
# min    1980.000000     74.940000       6.622000  12.273000 -19.700000
# 25%    1990.000000    278.502000      16.020000  17.205000  -3.198000
# 50%    2000.000000   1076.850000      52.373000  19.403000   4.750000
# 75%    2010.000000   3169.300000     102.094000  22.433000  11.440000
# max    2020.000000  10646.770000     208.669000  28.550000  32.069000
#
#          Exports           Go          ER         TOT
# count  41.000000    41.000000   41.000000   41.000000
# mean    3.832415   581.787390   58.627317   -3.056644
# std     7.814053   768.202213   32.170384   34.110581
# min   -13.375000    20.000000    7.420000 -142.394366
# 25%    -2.046000    63.724000   22.910000   -0.346136
# ...

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot(data[' ER'])
 
# show plot
plt.show()

# %%
data.columns
# Add label for vertical axis
# Out:
# Index(['YEAR', 'GDP', ' GDP_DEFLATOR', ' Inv', 'Imports', ' Exports', ' Go',
#        ' ER', 'TOT'],
#       dtype='object')

# %%
 sns.barplot(x = 'YEAR',y = ' ER',data = data)
 plt.show()

# %%
sns.histplot(data.GDP,kde=True)

# %%
sns.relplot(data=data, x="YEAR", y=" ER", kind="line")
