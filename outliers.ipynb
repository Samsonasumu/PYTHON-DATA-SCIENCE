# %% [markdown]
# <a href="https://colab.research.google.com/github/Samsonasumu/PYTHON-DATA-SCIENCE/blob/main/outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/grades (1).csv",index_col=False)

# %%
df.head()
# Out:
#    Student_ID  Test_Score
# 0           1          68
# 1           2          12
# 2           3          51
# 3           4          63
# 4           5          67

# %% [markdown]
# ## Z SCORE TO FIND OUTLIERS

# %%
for col in df.columns:
  col_zscore = col + '_zscore'

  df[col_zscore]= (df[col]-df[col].mean())/df[col].std(ddof=0)

# %%
df['outlier'] = (abs(df['Test_Score_zscore'])>3).astype(int)

# %%
df.tail()
# Out:
#     Student_ID  Test_Score  Student_ID_zscore  Test_Score_zscore  outlier
# 95          96          55           1.576245          -0.395896        0
# 96          97          59           1.610888          -0.085389        0
# 97          98          99           1.645531           3.019680        1
# 98          99          58           1.680173          -0.163016        0
# 99         100          60           1.714816          -0.007763        0

# %%
df.columns
# Out:
# Index(['Student_ID', 'Test_Score', 'Student_ID_zscore', 'Test_Score_zscore',
#        'outlier'],
#       dtype='object')

# %%
df.drop(columns=['Student_ID_zscore'],inplace=True)

# %%
df
# Out:
#     Student_ID  Test_Score  Test_Score_zscore  outlier
# 0            1          68           0.613251        0
# 1            2          12          -3.733846        1
# 2            3          51          -0.706403        0
# 3            4          63           0.225118        0
# 4            5          67           0.535625        0
# ..         ...         ...                ...      ...
# 95          96          55          -0.395896        0
# 96          97          59          -0.085389        0
# 97          98          99           3.019680        1
# 98          99          58          -0.163016        0
# 99         100          60          -0.007763        0
#
# [100 rows x 4 columns]

# %%
df.loc[df.outlier==1]
# Out:
#     Student_ID  Test_Score  Test_Score_zscore  outlier
# 1            2          12          -3.733846        1
# 9           10           8          -4.044353        1
# 42          43           2          -4.510114        1
# 97          98          99           3.019680        1

# %% [markdown]
# ## USING INTERQUARTILE RANGE TO DETECT OUTLIERS

# %%
df_q = pd.read_csv("/content/grades (1).csv")

# %%
Q1= df_q.Test_Score.quantile(0.25)
Q3= df_q.Test_Score.quantile(0.75)
Q1, Q3
# Out:
# (58.0, 66.25)

# %%
IQR = Q3-Q1

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (45.625, 78.625)

# %%
df_q[(df_q.Test_Score<lower_limit)|(df_q.Test_Score> upper_limit) ]
# Out:
#     Student_ID  Test_Score
# 1            2          12
# 9           10           8
# 15          16          42
# 17          18          41
# 42          43           2
# 44          45          43
# 47          48          79
# 50          51          41
# 53          54          81
# 55          56          80
# 85          86          23
# 88          89          81
# 97          98          99

# %%
df_no_outliers = df_q[(df_q.Test_Score<lower_limit)|(df_q.Test_Score> upper_limit) ]
df_no_outliers.shape
# Out:
# (13, 2)
