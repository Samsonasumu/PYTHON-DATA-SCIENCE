# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("/content/FinalTeamProject Dataset.xlsx")

# %%
df.head()
# Out:
#   Companies    MScore Fraud or Non Fraud  Return on Assets  Current Ratio  \
# 0       XOM -2.389523          Non Fraud          0.067980       1.044330
# 1       JNJ -3.305048          Non Fraud          0.114703       1.348317
# 2         V -3.262427          Non Fraud          0.174934       1.448473
# 3       WMT -3.321651          Non Fraud          0.055840       0.927797
# 4       CVX -3.039177          Non Fraud          0.065231       1.259303
#
#    Quick Ratio  Accounts Receivable Turnover  Accounts Payable Turnover  \
# 0     0.712780                     42.718239                  35.119899
# 1     1.118649                     59.485950                  43.029326
# 2     1.448473                     49.214603                   4.234050
# 3     0.281063                      5.276611                  35.216280
# 4     1.023963                     43.204857                  38.595620
#
#    Asset Turnover  Gross Profit Margin  ...  Accounts receivable  \
# ...

# %%
df.describe()
# Out:
#              MScore  Return on Assets  Current Ratio  Quick Ratio  \
# count  1.577000e+03       1577.000000    1577.000000  1577.000000
# mean  -1.414194e+03        -17.218083       3.426707     3.003912
# std    7.532558e+04        679.562446      15.531591    15.456376
# min   -2.893110e+06     -26985.844665       0.046152    -0.563750
# 25%   -3.573374e+00         -0.011462       1.066572     0.794059
# 50%   -3.297539e+00          0.034867       1.598968     1.227203
# 75%   -2.990423e+00          0.075620       2.535613     2.008951
# max    7.312098e+05         40.606679     335.646478   335.646478
#
#        Accounts Receivable Turnover  Accounts Payable Turnover  \
# count                  1.577000e+03                1577.000000
# mean                   1.094914e+05                  39.707032
# std                    4.344398e+06                  55.454141
# min                   -4.263865e+01                   0.000000
# ...

# %%
df.isnull().mean().sort_values(ascending=False) * 100
# Out:
# Companies                              0.0
# Accounts payable                       0.0
# Working Capital to Total Assets        0.0
# Cash to Total Assets                   0.0
# Cash to Total Liabilities              0.0
# Current Assets to Total Assets         0.0
# Current Liabilities to Total Assets    0.0
# Accounts receivable                    0.0
# EBITDA                                 0.0
# MScore                                 0.0
# Rating                                 0.0
# R_Score                                0.0
# Enterprise Value                       0.0
# MarketCap                              0.0
# Rev_Growth                             0.0
# NI_Growth                              0.0
# EBITDATA                               0.0
# EBITDAR                                0.0
# Total Liabilities/ Total Assets        0.0
# Debt to Equity                         0.0
# Net Profit/ Total Liabilities          0.0
# Net Profit/ Total Assets               0.0
# ...

# %% [markdown]
# # data prepreocessing

# %%
from sklearn.preprocessing import LabelEncoder
# Create an instance of LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the data
#encoded_data = label_encoder.fit_transform(df['Purchased Bike'])
df['FraudorNonFraud'] = label_encoder.fit_transform(df['Fraud or Non Fraud'])
# Print the encoded data
data = df.drop(['Fraud or Non Fraud'], axis=1)

# %%
data.head()
# Out:
#   Companies    MScore  Return on Assets  Current Ratio  Quick Ratio  \
# 0       XOM -2.389523          0.067980       1.044330     0.712780
# 1       JNJ -3.305048          0.114703       1.348317     1.118649
# 2         V -3.262427          0.174934       1.448473     1.448473
# 3       WMT -3.321651          0.055840       0.927797     0.281063
# 4       CVX -3.039177          0.065231       1.259303     1.023963
#
#    Accounts Receivable Turnover  Accounts Payable Turnover  Asset Turnover  \
# 0                     42.718239                  35.119899        0.816386
# 1                     59.485950                  43.029326        0.515196
# 2                     49.214603                   4.234050        0.342803
# 3                      5.276611                  35.216280        2.339108
# 4                     43.204857                  38.595620        0.649617
#
#    Gross Profit Margin  Net Profit Margin  ...  Accounts payable  \
# ...

# %%
data.columns
# Out:
# Index(['Companies', 'MScore', 'Return on Assets', 'Current Ratio',
#        'Quick Ratio', 'Accounts Receivable Turnover',
#        'Accounts Payable Turnover', 'Asset Turnover', 'Gross Profit Margin',
#        'Net Profit Margin', 'Return on Equity', 'Cash to Current Liabilities',
#        'Net Profit/ Total Assets', 'Net Profit/ Total Liabilities',
#        'Debt to Equity', 'Total Liabilities/ Total Assets', 'EBITDAR',
#        'EBITDATA', 'Working Capital to Total Assets', 'Cash to Total Assets',
#        'Cash to Total Liabilities', 'Current Assets to Total Assets',
#        'Current Liabilities to Total Assets', 'Accounts receivable',
#        'Accounts payable', 'EBITDA', 'Rating', 'R_Score', 'Enterprise Value',
#        'MarketCap', 'Rev_Growth', 'NI_Growth', 'Debt Growth',
#        'FraudorNonFraud'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

features = [ 'MScore', 'Return on Assets', 'Current Ratio',
       'Quick Ratio', 'Accounts Receivable Turnover',
       'Accounts Payable Turnover', 'Asset Turnover', 'Gross Profit Margin',
       'Net Profit Margin', 'Return on Equity', 'Cash to Current Liabilities',
       'Net Profit/ Total Assets'
       ]
X = data[features]
# Split the data into features and target variable
#X = data.drop('fraud', axis=1)
y = data['FraudorNonFraud']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Create and train the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Confusion Matrix
confusion_matrix_plot = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", confusion_matrix_plot)

# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[ 12  17]
#  [  1 286]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.41      0.57        29
#            1       0.94      1.00      0.97       287
#
#     accuracy                           0.94       316
#    macro avg       0.93      0.71      0.77       316
# weighted avg       0.94      0.94      0.93       316

# %%
from sklearn.metrics import accuracy_score
# Calculate the accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy score:", accuracy)
# Out:
# Accuracy score: 0.9430379746835443

# %% [markdown]
# # correaltion

# %%
plt.figure(figsize=(9, 6))
heatmap = sns.heatmap(data.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap of the variables', fontdict={'fontsize':12}, pad=12);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-27e546475040> in <cell line: 2>()
#       1 plt.figure(figsize=(9, 6))
# ----> 2 heatmap = sns.heatmap(data.corr(), vmin=-1, vmax=1, annot=True)
#       3 heatmap.set_title('Correlation Heatmap of the variables', fontdict={'fontsize':12}, pad=12);
#       4
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# ...

# %%
import pandas as pd

# Assuming 'data' is your DataFrame
numerical_data = data.select_dtypes(include=[np.number])  # Select numerical columns

# Rest of your code
plt.figure(figsize=(33, 13))
heatmap = sns.heatmap(numerical_data.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap of the variables', fontdict={'fontsize':12}, pad=12);
